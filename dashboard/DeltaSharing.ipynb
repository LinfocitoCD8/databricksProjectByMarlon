# %%
# %sql
SHOW GRANTS ON METASTORE

# %%
# %sql
CREATE SHARE dailys_SHARE;

# %%
# %sql
ALTER SHARE dailys_SHARE 
ADD TABLE catalog_dev.golden.daily_sales
WITH HISTORY

# %%
# %sql
ALTER SHARE dailys_SHARE 
ADD TABLE catalog_dev.golden.sales_by_category
WITH HISTORY

# %%
# %sql
ALTER SHARE dailys_SHARE 
ADD TABLE catalog_dev.golden.top_products
WITH HISTORY

# %%
# %sql
CREATE RECIPIENT ExternalCompanys

# %%
# %sql
GRANT SELECT 
ON SHARE dailys_SHARE
TO RECIPIENT ExternalCompanys
