# %%
# %python
dbutils.widgets.removeAll()

# %%
# %sql
CREATE WIDGET TEXT storageName default="adlproyectomarlon"

# %%
# %python
storageName = dbutils.widgets.get("storageName")

# %% [markdown]
# #Eliminacion de external locations

# %%
# %sql
DROP EXTERNAL LOCATION IF EXISTS `extl-metastore` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-raw` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-bronze` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-silver` FORCE;
DROP EXTERNAL LOCATION IF EXISTS `extl-golden` FORCE;

# %% [markdown]
# #Eliminacion de catalogo

# %%
# %sql
DROP CATALOG IF EXISTS catalog_dev CASCADE;

# %% [markdown]
# #Eliminacion de Schemas

# %%
# %sql
DROP SCHEMA IF EXISTS catalog_dev.raw;
DROP SCHEMA IF EXISTS catalog_dev.bronze;
DROP SCHEMA IF EXISTS catalog_dev.silver;
DROP SCHEMA IF EXISTS catalog_dev.golden;

# %% [markdown]
# #Eliminacion de tables

# %%
# %sql
DROP TABLE IF EXISTS catalog_dev.golden.daily_sales;
DROP TABLE IF EXISTS catalog_dev.golden.top_products;
DROP TABLE IF EXISTS catalog_dev.golden.sales_by_category;

DROP TABLE IF EXISTS catalog_dev.silver.sales_cleaned_grouped;

DROP TABLE IF EXISTS catalog_dev.bronze.everyday_sales;
DROP TABLE IF EXISTS catalog_dev.bronze.items;

# %% [markdown]
# #Eliminacion de rutas fisicas del Data lake

# %%
# %python
#dbutils.fs.rm(f"abfss://bronze@adlproyectomarlon.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://silver@adlproyectomarlon.dfs.core.windows.net/",True)
#dbutils.fs.rm(f"abfss://golden@adlproyectomarlon.dfs.core.windows.net/",True)
