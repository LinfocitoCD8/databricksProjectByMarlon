# %%
# %sql
-- Permiso a usuario
GRANT ALL PRIVILEGES ON CATALOG catalog_dev TO `joshycb2809@gmail.com`;

# %%
# %sql
-- PERMISOS ESQUEMAS A GRUPO
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_dev.bronze to `DataAnalyst`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_dev.silver to `DataAnalyst`;
GRANT CREATE, USE SCHEMA ON SCHEMA  catalog_dev.golden to `DataAnalyst`;

# %%
# %sql
-- PERMISOS TABLAS A GRUPO
GRANT SELECT ON TABLE catalog_dev.bronze.everyday_sales TO `DataAnalyst`;
GRANT SELECT ON TABLE catalog_dev.silver.sales_cleaned_grouped TO `DataAnalyst`;
GRANT SELECT ON TABLE catalog_dev.golden.daily_sales TO `DataAnalyst`;
GRANT SELECT ON TABLE catalog_dev.golden.sales_by_category TO `DataAnalyst`;
GRANT SELECT ON TABLE catalog_dev.golden.top_products TO `DataAnalyst`;

# %%
# %sql
-- PERMISO A EXTERNAL LOCATIONS A DATA ARCHITECTS
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-metastore` TO DataArchitects;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` TO DataArchitects;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` TO DataArchitects;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` TO DataArchitects;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` TO DataArchitects;

# %%
# %sql
-- PERMISO DE TABLA GOLDEN A DATA SCIENTIST
GRANT SELECT ON TABLE catalog_dev.golden.daily_sales TO DataScientist
